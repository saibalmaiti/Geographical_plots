# %%
import geopandas as gpd
import folium
from folium import Marker,Circle,Choropleth
from folium.plugins import HeatMap, MarkerCluster
import numpy as np
import pandas as pd
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-18ebf388fd8b> in <module>
# ----> 1 import geopandas as gpd
#       2 #import folium
#       3 #from folium import Marker,Circle,Choropleth
#       4 #from folium.plugins import HeatMap, MarkerCluster
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
def embed_map(m,file_name):
    from IPython.display import IFrame
    m.save(file_name) 
    return IFrame(file_name,width='100%',height='500px')

# %%
m_1=folium.Map(location=[42.32,-71.0589],tiles='openstreetmap',zoom_control=10)
embed_map(m_1,'m_1.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ce30f653682> in <module>
# ----> 1 m_1=folium.Map(location=[42.32,-71.0589],tiles='openstreetmap',zoom_control=10)
#       2 embed_map(m_1,'m_1.html')
#
# NameError: name 'folium' is not defined

# %%
df = pd.read_csv('crime.csv',encoding='latin-1')
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# 0      Sunday    13    Part One   LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST  42.275365 -71.090361
#
#                       Location
# 0  (42.35779134, -71.13937053)
# 1  (42.30682138, -71.06030035)
# 2  (42.34658879, -71.07242943)
# 3  (42.33418175, -71.07866441)
# 4  (42.27536542, -71.09036101)

# %%
daytime_robberies = df[((df.OFFENSE_CODE_GROUP=='Robbery') & \
                      (df.HOUR.isin(range(9,18))))]

# %%
daytime_robberies.head()
# Out:
#     INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP    OFFENSE_DESCRIPTION  \
# 42       I182070888           301            Robbery       ROBBERY - STREET
# 62       I182070865           301            Robbery       ROBBERY - STREET
# 299      I182070598           311            Robbery   ROBBERY - COMMERCIAL
# 527      I182070342           381            Robbery  ROBBERY - CAR JACKING
# 562      I182070309           361            Robbery        ROBBERY - OTHER
#
#     DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 42        A1             76      NaN  2018-09-03 15:45:00  2018      9
# 62       NaN                     NaN  2018-09-03 15:54:00  2018      9
# 299      A15             60      NaN  2018-09-02 17:15:00  2018      9
# 527      E18            490      NaN  2018-09-01 17:05:00  2018      9
# 562       D4            151      NaN  2018-09-01 15:00:00  2018      9
#
#     DAY_OF_WEEK  HOUR  UCR_PART          STREET        Lat       Long  \
# 42       Monday    15  Part One             NaN        NaN        NaN
# 62       Monday    15  Part One             NaN  42.315809 -71.098290
# 299      Sunday    17  Part One  RUTHERFORD AVE  42.371673 -71.063264
# 527    Saturday    17  Part One     CUMMINS HWY  42.276453 -71.112980
# 562    Saturday    15  Part One     BERKELEY ST  42.346055 -71.070507
#
#                         Location
# 42      (0.00000000, 0.00000000)
# 62   (42.31580852, -71.09829029)
# 299  (42.37167264, -71.06326413)
# 527  (42.27645319, -71.11297971)
# 562  (42.34605510, -71.07050669)

# %%
daytime_robberies.dropna(subset=['Lat', 'Long', 'DISTRICT'], inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
m_2=folium.Map(location=[42.32,-71.0589],tiles='cartodbpositron',zoom_control=13)

for idx, row in daytime_robberies.iterrows():
    Marker([row['Lat'],row['Long']]).add_to(m_2)
embed_map(m_2,'m_2.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a42d37d2de26> in <module>
# ----> 1 m_2=folium.Map(location=[42.32,-71.0589],tiles='cartodbpositron',zoom_control=13)
#       2
#       3 for idx, row in daytime_robberies.iterrows():
#       4     Marker([row['Lat'],row['Long']]).add_to(m_2)
#       5 embed_map(m_2,'m_2.html')
#
# NameError: name 'folium' is not defined

# %%
m_3 = folium.Map(location=[42.32,-71.0589],tiles='cartodbpositron',zoom_control=13)

mc = MarkerCluster()
for idx, row in daytime_robberies.iterrows():
     if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(Marker([row['Lat'], row['Long']]))
m_3.add_child(mc)

embed_map(m_3,'m_3.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-847322fb95de> in <module>
# ----> 1 m_3 = folium.Map(location=[42.32,-71.0589],tiles='cartodbpositron',zoom_control=13)
#       2
#       3 mc = MarkerCluster()
#       4 for idx, row in daytime_robberies.iterrows():
#       5      if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
#
# NameError: name 'folium' is not defined

# %%
|
